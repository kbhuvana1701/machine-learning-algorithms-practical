# %%
import matplotlib.pyplot as plt

# %%
#Create a simple line chart
import matplotlib.pyplot as plt   
x = [5, 6] 
y = [5, 6] 
plt.plot(x, y)  
plt.show()

# %%
#Create a simple line chart
import matplotlib.pyplot as plt   
x = [5, 6] 
y = [5, 6]  
plt.plot(x, y, marker='*')   
plt.show()

# %%
#Create a simple line chart 
import matplotlib.pyplot as plt
x = [5, 6, 9]
y = [5, 6, 20]
plt.plot(x, y, marker='*') 
plt.show()

# %%
#Create a simple line chart and title
import matplotlib.pyplot as plt 
x = [5, 6, 9]
y = [5, 6, 20]  
plt.title("Boss it is a line graph") 
plt.plot(x, y, marker='*')  
plt.show()

# %%
#Create a simple line chart and giving title and labelling 
import matplotlib.pyplot as plt   
x = [5, 6, 9] 
y = [5, 6, 20]
plt.title("A line graph") 
plt.xlabel("X values")  
plt.ylabel("Y values")   
plt.plot(x, y, marker = '*')  
plt.show()

# %%
#Create two lines in single chart
import matplotlib.pyplot as plt  
x = [5, 6, 9]
y = [5, 6, 20]
p = [10, 20, 25] 
plt.title("A line graph")
plt.xlabel("X values")   
plt.ylabel("Y values")  
plt.plot(x, y, marker = '*')
plt.plot(x, p, marker = '*')   
plt.show()

# %%
#Creating bar chart 
import matplotlib.pyplot as plt    
months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"] 
sales = [23, 45, 56, 78, 213, 45, 78, 89, 99, 100, 101, 130] 
plt.title('A Bar Graph')  
plt.xlabel('Month')   
plt.ylabel('Product Sales') 
plt.bar(months, sales)   
plt.show()

# %%
#Creating horizontal  bar chart
import matplotlib.pyplot as plt   
months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"] 
sales = [23, 45, 56, 78, 213, 45, 78, 89, 99, 100, 101, 130] 
plt.title('A Bar Graph')    
plt.xlabel('Product Sales')  
plt.ylabel('Month')   
plt.barh(months, sales) 
plt.show()

# %%
#Creating horizontal  bar chart 
import matplotlib.pyplot as plt 
import pandas as pd  
df = pd.read_csv("insurance.csv")
plt.title('A Bar Graph') 
plt.xlabel('age')   
plt.ylabel('bmi') 
plt.bar(df.age, df.bmi)
plt.show()

# %%
plt.bar(df.age, df.bmi)
plt.show()

# %%
#Creating bar chart 
import matplotlib.pyplot as plt  
months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
sales = [20, 40, 50, 70, 210, 40, 70, 80, 90, 100, 120, 130] 
plt.title('A Bar Graph')  
plt.xlabel('Month') 
plt.ylabel('Product Sales')  
plt.bar(months, sales, width = 1.0)
plt.show()

# %%
#Creating histogram 
import matplotlib.pyplot as plt 
data = [12, 15, 13, 20, 19, 20, 11, 19, 11, 12, 19, 13, 15, 16, 18, 13]   
plt.xlabel("X") 
plt.ylabel("Y")
plt.title("Histogram Plot") 
plt.hist(data, bins = 20)
plt.show()

# %%
#Creating pie chart 
import matplotlib.pyplot as plt
students=['bhuvana','mahitha','vishwa']
points=[62,60,48]
plt.pie(points,labels=students)
plt.axis('equal')
plt.show()

# %%
#Creating pie chart 
import matplotlib.pyplot as plt 
students = ['minsuu', 'mahiii', 'siri']
points = [62, 48, 36] 
c = ['y', 'r', 'b']    
plt.pie(points, labels = students, colors = c , shadow = True, 
explode = (0.05, 0.05, 0.05), autopct = '%1.1f%%')   
plt.axis('equal') 
plt.legend() 
plt.show()

# %%
#Creating Scatter plot 
import matplotlib.pyplot as plt    
area = [1, 2, 3, 4, 5]
rice_packs = [10, 20, 30, 40, 50] 
plt.xlabel('area')
plt.ylabel('rice packs')  
plt.scatter(area, rice_packs)
plt.show()

# %%
#Creating Scatter plot
import matplotlib.pyplot as plt   
area = [1, 2, 3.5, 4, 5] 
rice_packs = [7, 14, 22, 30, 40]  
plt.xlabel('area')
plt.ylabel('rice packs')
plt.scatter(area, rice_packs) 
plt.show()

# %%
#Creating box plot 
import matplotlib.pyplot as plt  
data = [10, 20, 30, 40, 50]  
plt.boxplot(data) 
plt.show()

# %%
#Creating box plot with outlier
import matplotlib.pyplot as plt  
data = [10, 20, 30, 40, 50, 90]
plt.boxplot(data)  
plt.show()

# %%
#creating box plot
import matplotlib.pyplot as plt  
import pandas as pd 
d = {      
     "Apple": [10, 20, 30, 40],   
     "Orange": [7, 14, 21, 28],     
     "Banana": [55, 15, 8, 12],     
     "Pear": [15, 14, 1, 8] 
} 
i = ['Basket1', 'Basket2', 'Basket3', 'Basket4'] 
df = pd.DataFrame(d, index = i)  
plt.imshow(df, cmap = "YlGnBu") 
plt.colorbar() 
plt.xticks(range(len(df)), df.columns)
plt.yticks(range(len(df)), df.index) 
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\nirma\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\nirma\anaconda3\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\nirma\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\nirma\anaconda3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nirma\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nirma\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nirma\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading titanic dataset 
import seaborn as sns
df = sns.load_dataset('titanic') 
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Number of rows and columns
import seaborn as sns   
df = sns.load_dataset('titanic')
print(df.shape)
# Out:
# (891, 15)

# %%
#Display the columns 
import seaborn as sns 
df = sns.load_dataset('titanic')
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#dataframe information 
import seaborn as sns
df = sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#unique values for sex(gender) column 
result = df['sex'].unique()
print(result)
# Out:
# ['male' 'female']

# %%
#describe() method 
print(df.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Creating bar plot 
sns.barplot(x = 'sex', y = 'age', data = df)
plt.show()

# %%
#Get a count of the number of survivors 
print(df['survived'].value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#Get a count of the number of survivors  
import matplotlib.pyplot as plt  
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')   
df = sns.load_dataset('titanic')
sns.countplot(x = "survived", data = df)  
plt.show()

# %%
#Plot the survival rate of each class 
df = sns.load_dataset('titanic')
sns.barplot(x = 'class', y = 'survived', data = df)
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
#Plot the survival rate of each class 
result = df.pivot_table('survived', index = 'sex', columns = 'class') 
print(result)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
#Plot the survival rate by gender, age and class 
diff_ages = pd.cut(df['age'], [0, 18, 80]) 
result = df.pivot_table('survived', ['sex', diff_ages], 'class')
print(result)
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
#Finding Most of the tickets, using dist plot 
sns.distplot(df['fare'], kde = False)  
plt.show()

# %%
#Creating a boxplot with sex column(gender) survived 
sns.boxplot(x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Creating a boxplot with survived 
sns.boxplot(x = 'sex', y = 'age', data = df, hue = "survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Creating violin plot 
sns.violinplot(x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#Creating violin plot with survived 
sns.violinplot(x = 'sex', y = 'age', data = df, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\nirma\anaconda3\lib\site-packages (1.9.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\nirma\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\nirma\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\nirma\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nirma\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Wordcloud example 
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
text = "DataScience having good career path, DataScience is cutting edge technology, DataScience course is existing in nit, bhuvana used to teach DataScience, if we learn DataScience then we will get good package"
wc = WordCloud() 
wc.generate(text)  
plt.figure(figsize = (12, 12)) 
plt.imshow(wc) 
plt.axis('off') 
plt.show()

# %%
#Wordcloud example 
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
text = "Small steps every day create big results Stay patient, your time will comeProgress matters more than perfectionBelieve in yourself and keep moving forwardEvery sunset brings a new sunrise"
wc = WordCloud() 
wc.generate(text)  
plt.figure(figsize = (12, 12)) 
plt.imshow(wc) 
plt.axis('off') 
plt.show()

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\nirma\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nirma\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\nirma\anaconda3\lib\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Sunburst plot example 
import plotly.express as px 
figure = px.sunburst(data, path = ["day", "sex"], values = "total_bill")
figure.show()
