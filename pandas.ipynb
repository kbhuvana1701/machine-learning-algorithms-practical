# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name="numbers"
print(s.name)
# Out:
# numbers

# %%
print(s.name)
# Out:
# numbers

# %%
#indexing
s[0]
# Out:
# np.int64(10)

# %%
s[0:2]
# Out:
# 0    10
# 1    20
# Name: numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
#iloc -location based indexing
s.iloc[3]
# Out:
# np.int64(40)

# %%
s[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,2,3]]
# Out:
# 1    20
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
id=[100,200,300,400,500]
s.index=id
s
# Out:
# 100    10
# 200    20
# 300    30
# 400    40
# 500    50
# Name: numbers, dtype: int64

# %%
s[200]
# Out:
# np.int64(20)

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.loc[100:300]
# Out:
# 100    10
# 200    20
# 300    30
# Name: numbers, dtype: int64

# %%
class_data={"name":1,"marks":100,"Age":20,"Subject":4}

# %%
s2=pd.Series(class_data,name="College")
s2
# Out:
# name         1
# marks      100
# Age         20
# Subject      4
# Name: College, dtype: int64

# %%
s2.iloc[3]
# Out:
# np.int64(4)

# %%
s2.loc["Age"]
# Out:
# np.int64(20)

# %%
#Conditional selection
s2[s2>20]
# Out:
# marks    100
# Name: College, dtype: int64

# %%
#Logical Operators
s2[(s2>4) &(s2<100)]
# Out:
# Age    20
# Name: College, dtype: int64

# %%
s2[~(s2>20)]
# Out:
# name        1
# Age        20
# Subject     4
# Name: College, dtype: int64

# %%
#modify the series
s2["Age"]=34
3
s2
# Out:
# name         1
# marks      100
# Age         34
# Subject      4
# Name: College, dtype: int64

# %%
#dataframes

# %%
import numpy as np
import pandas as pd
ser=pd.Series(['a',np.nan,1,np.nan,2])
ser.notnull().sum()
# Out:
# np.int64(3)

# %%
data={
      "Name":["krish","kumar","reddy","minsuu","mahitha","vishwa"],
      "Age":[25,34,32,42,33,43],
      "Department":["HR","IT","Finance","IT","HR","HR"],
      "Salary":[50000,60000,70000,62000,np.nan,50000]
}
data
# Out:
# {'Name': ['krish', 'kumar', 'reddy', 'minsuu', 'mahitha', 'vishwa'],
#  'Age': [25, 34, 32, 42, 33, 43],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
data
# Out:
# {'Name': ['krish', 'kumar', 'reddy', 'minsuu', 'mahitha', 'vishwa'],
#  'Age': [25, 34, 32, 42, 33, 43],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name  Age Department   Salary
# 0    krish   25         HR  50000.0
# 1    kumar   34         IT  60000.0
# 2    reddy   32    Finance  70000.0
# 3   minsuu   42         IT  62000.0
# 4  mahitha   33         HR      NaN
# 5   vishwa   43         HR  50000.0

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.head(3)
# Out:
#     Name  Age Department   Salary
# 0  krish   25         HR  50000.0
# 1  kumar   34         IT  60000.0
# 2  reddy   32    Finance  70000.0

# %%
df.head(5)
# Out:
#       Name  Age Department   Salary
# 0    krish   25         HR  50000.0
# 1    kumar   34         IT  60000.0
# 2    reddy   32    Finance  70000.0
# 3   minsuu   42         IT  62000.0
# 4  mahitha   33         HR      NaN

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.head(3)
# Out:
#     Name  Age Department   Salary
# 0  krish   25         HR  50000.0
# 1  kumar   34         IT  60000.0
# 2  reddy   32    Finance  70000.0

# %%
df.tail(3)
# Out:
#       Name  Age Department   Salary
# 3   minsuu   42         IT  62000.0
# 4  mahitha   33         HR      NaN
# 5   vishwa   43         HR  50000.0

# %%
#loc and iloc
df.iloc[1:3]
# Out:
#     Name  Age Department   Salary
# 1  kumar   34         IT  60000.0
# 2  reddy   32    Finance  70000.0

# %%
df.loc[1:3]
# Out:
#      Name  Age Department   Salary
# 1   kumar   34         IT  60000.0
# 2   reddy   32    Finance  70000.0
# 3  minsuu   42         IT  62000.0

# %%
df.loc[1:3,["Age","Department"]]
# Out:
#    Age Department
# 1   34         IT
# 2   32    Finance
# 3   42         IT

# %%
df.loc[1:5,"Department"]
# Out:
# 1         IT
# 2    Finance
# 3         IT
# 4         HR
# 5         HR
# Name: Department, dtype: object

# %%
df.iloc[1:5,2:]
# Out:
#   Department   Salary
# 1         IT  60000.0
# 2    Finance  70000.0
# 3         IT  62000.0
# 4         HR      NaN

# %%
df.iloc[1:5,:2]
# Out:
#       Name  Age
# 1    kumar   34
# 2    reddy   32
# 3   minsuu   42
# 4  mahitha   33

# %%
df["Age"]
# Out:
# 0    25
# 1    34
# 2    32
# 3    42
# 4    33
# 5    43
# Name: Age, dtype: int64

# %%
df[["Age","Department"]]
# Out:
#    Age Department
# 0   25         HR
# 1   34         IT
# 2   32    Finance
# 3   42         IT
# 4   33         HR
# 5   43         HR

# %%
df.drop("Age",axis=1)
# Out:
#       Name Department   Salary
# 0    krish         HR  50000.0
# 1    kumar         IT  60000.0
# 2    reddy    Finance  70000.0
# 3   minsuu         IT  62000.0
# 4  mahitha         HR      NaN
# 5   vishwa         HR  50000.0

# %%
df
# Out:
#       Name  Age Department   Salary
# 0    krish   25         HR  50000.0
# 1    kumar   34         IT  60000.0
# 2    reddy   32    Finance  70000.0
# 3   minsuu   42         IT  62000.0
# 4  mahitha   33         HR      NaN
# 5   vishwa   43         HR  50000.0

# %%
df.drop("Age",axis=1,inplace=True)

# %%
df
# Out:
#       Name Department   Salary
# 0    krish         HR  50000.0
# 1    kumar         IT  60000.0
# 2    reddy    Finance  70000.0
# 3   minsuu         IT  62000.0
# 4  mahitha         HR      NaN
# 5   vishwa         HR  50000.0

# %%
df["Age"]=[32,35,35,20,np.nan,45]
df
# Out:
#       Name Department   Salary   Age
# 0    krish         HR  50000.0  32.0
# 1    kumar         IT  60000.0  35.0
# 2    reddy    Finance  70000.0  35.0
# 3   minsuu         IT  62000.0  20.0
# 4  mahitha         HR      NaN   NaN
# 5   vishwa         HR  50000.0  45.0

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Department  6 non-null      object
#  2   Salary      5 non-null      float64
#  3   Age         5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Salary        Age
# count      5.000000   5.000000
# mean   58400.000000  33.400000
# std     8532.291603   8.961027
# min    50000.000000  20.000000
# 25%    50000.000000  32.000000
# 50%    60000.000000  35.000000
# 75%    62000.000000  35.000000
# max    70000.000000  45.000000

# %%
df["Salary"]
# Out:
# 0    50000.0
# 1    60000.0
# 2    70000.0
# 3    62000.0
# 4        NaN
# 5    50000.0
# Name: Salary, dtype: float64

# %%
#Broadcasting
df["Salary"]=df["Salary"]+5000

# %%
df["Salary"]
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4        NaN
# 5    55000.0
# Name: Salary, dtype: float64

# %%
#rename
df.rename(columns={"Department":"Dept"},inplace=True)

# %%
df
# Out:
#       Name     Dept   Salary   Age
# 0    krish       HR  55000.0  32.0
# 1    kumar       IT  65000.0  35.0
# 2    reddy  Finance  75000.0  35.0
# 3   minsuu       IT  67000.0  20.0
# 4  mahitha       HR      NaN   NaN
# 5   vishwa       HR  55000.0  45.0

# %%
#Unique Values
df["Dept"].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df["Salary"].unique()
# Out:
# array([55000., 65000., 75000., 67000.,    nan])

# %%
#count
df["Dept"].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
df["Promoted_Salary"]=df["Salary"]*10

# %%
df
# Out:
#       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2    reddy  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0

# %%
#Data Cleaning
df.isnull().sum()
# Out:
# Name               0
# Dept               0
# Salary             1
# Age                1
# Promoted_Salary    1
# dtype: int64

# %%
df.dropna()
# Out:
#      Name     Dept   Salary   Age  Promoted_Salary
# 0   krish       HR  55000.0  32.0         550000.0
# 1   kumar       IT  65000.0  35.0         650000.0
# 2   reddy  Finance  75000.0  35.0         750000.0
# 3  minsuu       IT  67000.0  20.0         670000.0
# 5  vishwa       HR  55000.0  45.0         550000.0

# %%
df
# Out:
#       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2    reddy  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0

# %%
#if any of the row value is null del total row
df.dropna(how="any")
# Out:
#      Name     Dept   Salary   Age  Promoted_Salary
# 0   krish       HR  55000.0  32.0         550000.0
# 1   kumar       IT  65000.0  35.0         650000.0
# 2   reddy  Finance  75000.0  35.0         750000.0
# 3  minsuu       IT  67000.0  20.0         670000.0
# 5  vishwa       HR  55000.0  45.0         550000.0

# %%
#if all the values in the row them del whole row
df.dropna(how="all")
# Out:
#       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2    reddy  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0

# %%
#replace null values
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    32.0
# 1    35.0
# 2    35.0
# 3    20.0
# 4    33.4
# 5    45.0
# Name: Age, dtype: float64

# %%
#null value with median
df["Salary"].fillna(df["Salary"].median())
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4    65000.0
# 5    55000.0
# Name: Salary, dtype: float64

# %%
df["Age"].fillna(method="ffill")
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_13808\310954073.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method="ffill")
# 0    32.0
# 1    35.0
# 2    35.0
# 3    20.0
# 4    20.0
# 5    45.0
# Name: Age, dtype: float64

# %%
df["Age"].fillna(method="bfill")
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_13808\3345892411.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method="bfill")
# 0    32.0
# 1    35.0
# 2    35.0
# 3    20.0
# 4    45.0
# 5    45.0
# Name: Age, dtype: float64

# %%
#replacing a value
df["Name"]=df["Name"].replace("reddy","juliee")

# %%
df
# Out:
#       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2   juliee  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.loc[len(df)]=["Bob","HR",55000.0,45,550000.0]
df
# Out:
#       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2   juliee  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0
# 6      Bob       HR  55000.0  45.0         550000.0

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df_dup=df[df.duplicated(keep="first")]
df_dup
# Out:
# Empty DataFrame
# Columns: [Name, Dept, Salary, Age, Promoted_Salary]
# Index: []

# %%
import pandas as pd

# %%
df_dup=df[df.duplicated(keep="last")]
df_dup
# Out:
# Empty DataFrame
# Columns: [Name, Dept, Salary, Age, Promoted_Salary]
# Index: []

# %%
df=df.drop_duplicates
df
# Out:
# <bound method DataFrame.drop_duplicates of       Name     Dept   Salary   Age  Promoted_Salary
# 0    krish       HR  55000.0  32.0         550000.0
# 1    kumar       IT  65000.0  35.0         650000.0
# 2   juliee  Finance  75000.0  35.0         750000.0
# 3   minsuu       IT  67000.0  20.0         670000.0
# 4  mahitha       HR      NaN   NaN              NaN
# 5   vishwa       HR  55000.0  45.0         550000.0
# 6      Bob       HR  55000.0  45.0         550000.0>

# %%
'''name="alice_fernandes"
df[["first_name","last_name"]]=df["name"].str.split("_")'''
# Out:
# 'name="alice_fernandes"\ndf[["first_name","last_name"]]=df["name"].str.split("_")'

# %%
#apply and lambda
def multiplying_age(x):
                       return x*2
                       df["Age"]=df["Age"].apply(multiplying_age)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#joins and merges
department_info={
"Dept":["HR","IT","Finance"],
"Location":["New York","San Francisco","Chicago"],
"Manager":["Laura","Steve","Nina"]
}
df2=pd.DataFrame(department_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 #joins and merges
#       2 department_info={
#       3 "Dept":["HR","IT","Finance"],
#       4 "Location":["New York","San Francisco","Chicago"],
#       5 "Manager":["Laura","Steve","Nina"]
#       6 }
# ----> 7 df2=pd.DataFrame(department_info)
#
# NameError: name 'pd' is not defined

# %%
#concat
pd.concat([df,df2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #concat
# ----> 2 pd.concat([df,df2])
#
# NameError: name 'pd' is not defined

# %%
pd.concat([df,df2],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.concat([df,df2],axis=1)
#
# NameError: name 'pd' is not defined

# %%
pd.merge(df,df2,on="Dept")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.merge(df,df2,on="Dept")
#
# NameError: name 'pd' is not defined
